# %%
# Crie um banco para cada organismo
# !makeblastdb -in data_targets/c_sinensis_data/ncbi_dataset/data/GCF_022201045.2/cds_from_genomic.fna -dbtype nucl -title "Citrus" -out db_citrus
# Out:
# Building a new DB, current time: 02/05/2026 19:49:41
# New DB name:   /home/denilson/rep/dfb/c_abscissum/db_citrus
# New DB title:  Citrus
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 40427 sequences in 1.23233 seconds.

# %%
# !makeblastdb -in data_targets/h_sapiens_data/ncbi_dataset/data/GCF_000001405.40/cds_from_genomic.fna -dbtype nucl -title "Human" -out db_human
# Out:
# Building a new DB, current time: 02/05/2026 19:49:42
# New DB name:   /home/denilson/rep/dfb/c_abscissum/db_human
# New DB title:  Human
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 146337 sequences in 5.1163 seconds.

# %%
# !makeblastdb -in data_targets/a_melifera_data/ncbi_dataset/data/GCF_003254395.2/cds_from_genomic.fna -dbtype nucl -title "Bee" -out db_bee
# Out:
# Building a new DB, current time: 02/05/2026 19:49:48
# New DB name:   /home/denilson/rep/dfb/c_abscissum/db_bee
# New DB title:  Bee
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 23471 sequences in 0.892065 seconds.
